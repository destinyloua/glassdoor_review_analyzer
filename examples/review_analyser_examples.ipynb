# %% [markdown]
# # Review Analyzer Examples
#
# This file is an example use of reviewanalyser class

# %%
import pandas as pd
from src.review_analyser import ReviewAnalyzer

# %% [markdown]
# ## Example 1: Basic Usage
#
# This example shows how to create a ReviewAnalyser object and perform basic analysis.

# %%
df = pd.DataFrame({
    "company_name": ["A", "B", "A"],
    "overall_rating": [4.0, 2.0, 3.0],
})

analyzer = ReviewAnalyzer(df)

analyzer.review_count()

analyzer.average_rating()

# %% [markdown]
# ##Example 2: Rating Buckets
#
# This example shows how to categorize ratings into low, medium, and high groups

# %%
analyzer.bucket_ratings()
